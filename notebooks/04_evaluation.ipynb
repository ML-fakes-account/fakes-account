# %% [markdown]
# # 4 — Évaluation et comparaison
#
# **À faire :** accuracy, précision, rappel, F1-score, matrices de confusion pour chaque modèle ; tableau récapitulatif pour le rapport et pour alimenter le frontend / `backend/app.py`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from sklearn.metrics import classification_report

print(classification_report.__doc__.split("\n")[0])
