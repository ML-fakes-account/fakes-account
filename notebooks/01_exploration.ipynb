# %% [markdown]
# # 1 — Exploration des données (EDA)
#
# **À faire :** charger le jeu open data depuis `data/raw/`, décrire les variables, étudier les distributions, valeurs manquantes et équilibre des classes (faux vs authentiques).

# %%
from pathlib import Path
import sys

# Racine du dépôt : exécuter Jupyter depuis la racine ``fakes-account``
ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.paths import DATA_RAW, DATA_PROCESSED
from src.data_loading import load_csv

print("Données brutes :", DATA_RAW)
print("Données traitées :", DATA_PROCESSED)
