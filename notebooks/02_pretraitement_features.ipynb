# %% [markdown]
# # 2 — Prétraitement et sélection des features
#
# **À faire :** imputation ou suppression des valeurs manquantes, encodage des catégories, gestion simple des outliers, normalisation si nécessaire (KNN, SVM), sauvegarde d’un jeu nettoyé dans `data/processed/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.paths import DATA_PROCESSED

DATA_PROCESSED.mkdir(parents=True, exist_ok=True)
print("Sortie prévue pour les données préparées :", DATA_PROCESSED)
