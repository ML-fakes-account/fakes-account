# %% [markdown]
# # 3 — Entraînement des modèles
#
# **À faire :** séparation train/test, entraînement de plusieurs classificateurs scikit-learn (régression logistique, KNN, arbre, Random Forest, SVM, Naïve Bayes), sauvegarde des estimateurs avec `joblib` dans `models/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.paths import MODELS_DIR

MODELS_DIR.mkdir(parents=True, exist_ok=True)
print("Dossier des modèles sauvegardés :", MODELS_DIR)
